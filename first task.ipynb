# %%
f= open("seq.fa", "r")

# %%
f.seek(0)

# %%
h1= f.readline()
s1= f.readline()

# %%
h2= f.readline()
s2= f.readline()

# %%
h3= f.readline()
s3= f.readline()

# %%
print h1+s1+h2+s2+h3+s3
# Out:
# >gi|850499417|ref|NZ_JJQA01000077.1| Methanosarcina mazei strain 1.F.A.1A.3 scaffold43_1_size26087-refined, whole genome shotgun sequence
# ...
# >gi|851311151|ref|NZ_JJOZ01000058.1| Methanosarcina sp. 2.H.T.1A.8 scaffold39_1_size28955-refined, whole genome shotgun sequence
# ...
# >gi|814739419|gb|JJOZ01000058.1| Methanosarcina sp. 2.H.T.1A.8 scaffold39_1_size28955-refined, whole genome shotgun sequence
# ...
